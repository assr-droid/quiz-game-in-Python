# %%
print ("Welcome to the game. 😃💁")
# Out:
# Welcome to the game. 😃💁

# %%
playing = input('Do you want to play? ')
# Out:
# Do you want to play?  yes

# %%
if playing.lower() != 'yes':
    quit()
print('Okay lets play!')

ans = input ('True or False: All birds can fly. \n')
if ans.lower() == 'false':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')
    
ans = input ('True or False: All mammals lay eggs. \n')
if ans.lower() == 'false':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')

ans = input ('True or False: Water boils at 100 degrees Fahrenheit. \n')
if ans.lower() == 'false':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')

ans = input ('How many sides does a hexagon have? (4/5/7/8/6) \n')
if ans == '6':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')

ans = input ('True or False: All prime numbers are odd. \n')
if ans.lower() == 'false':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')

ans = input ('True or False: The Earth is the largest planet in our solar system. \n')
if ans.lower() == 'false':
    print('Correctomundo!')
    pt=pt+1
else:
    print('Incorrect.')


    
print('\n Congratulations! You have scored', pt ,'points!')
# Out:
# Okay lets play!
# True or False: All birds can fly.
#  faLSE
# Correctomundo!
# True or False: All mammals lay eggs.
#  FASLE
# Incorrect.
# True or False: Water boils at 100 degrees Fahrenheit.
#  flase
# Incorrect.
# How many sides does a hexagon have? (4/5/7/8/6)
#  false
# Incorrect.
# True or False: All prime numbers are odd.
#  false
# Correctomundo!
# True or False: The Earth is the largest planet in our solar system.
#  false
# Correctomundo!
# Congratulations! You have scored 7 points!
